# %%
print('hello world')
# Out:
# hello world

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic'

# %%
from pathlib import Path


cwd = Path.cwd()
cwd
# Out:
# PosixPath('/content')

# %%
import os
os.listdir(cwd)
# Out:
# ['.config', 'drive', 'sample_data']

# %%
cwd = os.getcwd()
cwd
# Out:
# '/content'

# %%
os.chdir('/content/drive/MyDrive/Git/Programming_Practice/ML/TensorFlow_tutorial/01_ML basics with Keras')
cwd = os.getcwd()
cwd
# Out:
# '/content/drive/MyDrive/Git/Programming_Practice/ML/TensorFlow_tutorial/01_ML basics with Keras'

# %%
os.listdir(cwd)
# Out:
# ['aclImdb', 'aclImdb_v1.tar.gz.tar.gz']

# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1.tar.gz", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a93e31ba43e5> in <module>()
#       1 url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
#       2
# ----> 3 dataset = tf.keras.utils.get_file("aclImdb_v1.tar.gz", url,
#       4                                     untar=True, cache_dir='.',
#       5                                     cache_subdir='')
#
# NameError: name 'tf' is not defined

# %%
# !pwd
# Out:
# /content/drive/My Drive/Git/Programming_Practice/ML/TensorFlow_tutorial/01_ML basics with Keras

# %%
# !ls
# Out:
# aclImdb  aclImdb_v1.tar.gz.tar.gz
